# %%
import sys
sys.path.insert(0,'../scripts')
from pycap_for_PESTPP_MOU import prepare_MOU_files
from pathlib import Path
import zipfile
import pyemu

# %% [markdown]
# # First prepare the MOU files
# In the `../scripts` directory the script called `pycap_for_PESTPP_MOU.py` has all the logic required to configure a directory in which to run PEST++ MOU for a given configuration. In the next cell, 5 variables must be specified. They are outlined here:
#  -  `pump_lbound_fraction` is a lower bound on pumping, applied to each well used in the optimization. This takes the form of a fraction (typically between 0.0 and 1.0) to be multiplied by the baseline pumping rate to form a lower bound. *
#  -  `pump_ubound_fraction` is an upper bound on pumping, applied to each well used in the optimization. This takes the form of a fraction (typically around 1.0, but can be selected) to be multiplied by the baseline pumping rate to form a lower bound.
#  - `objectives` determined what the multiple objectives to be optimized for are. You can make more custom versions of this, but currently three options are supported:
#     - `depletion_q` aims to _minimize_ depletion (in CFS) and _maximize_ agricultural pumping (in CFS)
#     - `fish_q` aims to _maximize_ the probability of Brook trout presence (in %) and _maximize_ agricultural pumping (in CFS)
#     - `fish_dollars` aims to _maximize_ the probability of Brook trout presence (in %) and _maximize_ agricultural receipts (in cashmoney $$$)
# - `depletion_potential_threshold` is a threshold (in the range of 0.0 to 1.0) of depletion potential below which wells are not managed for optimization. In other words, if a well's depletion potential falls below the threshold, it is maintained at its original baseline pumping rate throughout the optimization process. A spatial analysis can help guide this decision - see notebook `01_Calculate_Depletion_Potential.ipynb` for guidance.
# - `scenario_name` will be assigned to both the configuration file saving these choices (and used by `06_MOU_postprocess.ipynb` for visualization and further analysis) and used to name the folder in which it will run.
#     - the file goes in a subdirectory within this notebooks directory (`notebooks/configurations`) and is named `<scenario_name>.yml`
#
#
# \* note that for the `fish_dollars` objectives set, there is a pumping threshold hard-coded that sets any pumping less than 70% of the baseline to 0.

# %%
run_name, run_path = prepare_MOU_files(pump_lbound_fraction=0.7,
                      pump_ubound_fraction=1.0,
                      objectives='depletion_q', #'depletion_q','fish_q', or 'fish_dollars'
                      depletion_potential_threshold=0.2,
                      scenario_name='los_pollos_run',)
# Out:
# wrote configuration to: configurations/los_pollos_run.yml
# error parsing metadata from 'obsnme', continuing
# noptmax:50, npar_adj:19, nnz_obs:1
# ALL READY TO RUN:
#  scenario: los_pollos_run
#  directory: ../pycap_runs/pycap_pest/run_los_pollos_run

# %% [markdown]
# # Now run PESTPP-MOU below - note, this might take 20 or 30 minutes or up to a couple hours depending on your computer*. Go have a ☕️ or a 🍺 and think about life choices (and note that if we were running with MODFLOW instead of pycap, this would take overnight on a few hundred computers in parallel #winning )
#
# #### *Accept this as one of the benefits of modeling. One day you will tell your boss 'yeah, i'm running a model right now' as you walk out the door to go for a bike ride"

# %%
pyemu.os_utils.run(f"pestpp-mou {run_name}.pst /e",cwd=str(run_path))
# Out:
# ./pestpp-mou los_pollos_run.pst /e
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
# ...processing command line: ' ./pestpp-mou los_pollos_run.pst /e'
# ...using external run manager
#
#
# version: 5.2.24
# binary compiled on Nov 12 2025 at 11:54:09
#
# using control file: "los_pollos_run.pst"
# in directory: "/Users/nkalauni/Documents/classes/4th-sem/564 Analysis/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_los_pollos_run"
# on host: "Mac"
# on a(n) apple operating system
# with release configuration
# started at 02/16/26 02:37:07
#
# processing control file los_pollos_run.pst
# parameter warning: 327 parameters are at upper bound
#               starting external run manager ...
#
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...saving generation specific populations and archives every nth generation 1
# using all adjustable parameters as decision variables:  19
# ...number of decision variables:  19
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluating chance at representative point
# ...using the following observations as objectives:
#        LPR:TOTAL_COMBINED:BDPL   minimize
# ...using the following prior info eqs as objectives:
#                       OBJ_WELL   maximize
# ...1 obs-based constraints/objectives, see rec file for listing
# ...1 pi-based constraints, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
# ...loading dv population from csv file initial_dvpop.csv
# ...dv population with 38 members read from 'initial_dvpop.csv'
#
# checking for denormal values in dv population
# ... saved initial dv population to  los_pollos_run.0.dv_pop.csv
# ...running initial population of size 38
# ...running population of size  38
# 02/16/26 02:37:07 external run manager calling forward run command(s)
# 02/16/26 02:37:07 calling forward run command: 'python run_pycap_standalone_opt_mou.py los_pollos_run'
# ...pid: 95096
# ...exit_code: 95096
# ...status: 0
# 02/16/26 02:37:16 forward run command(s) finished, took 9.439 seconds
# ... saved observation population to  los_pollos_run.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5     193.55      280.902      32.0859      223.932       327.77
# WELL_23645__Q            158.8     111.16      157.792      17.5889      129.709      188.332
# WELL_23653__Q            263.6     184.52      263.941      31.7008      212.885      315.432
# WELL_23755__Q            794.6     556.22      806.113      104.427      652.303      948.514
# WELL_23770__Q            239.9     167.93      244.102      28.3376        192.9      283.933
# WELL_23816__Q            149.4     104.58      148.807      17.5752       122.79      173.787
# WELL_23876__Q            197.6     138.32      190.564      21.6951      159.486      234.128
# WELL_23934__Q            370.6     259.42      370.245      38.4777      303.398      443.332
# WELL_24239__Q            271.5     190.05      268.145      30.7322      217.855      324.174
# WELL_24323__Q            206.4     144.48      211.803      23.9373      165.792      247.192
# WELL_466__Q              315.9     221.13      314.348      41.6365      255.835      378.944
# WELL_467__Q              296.9     207.83      293.367      30.9425      243.103      352.759
# WELL_58405__Q              418      292.6      419.251      45.9787      336.539      485.757
# WELL_68008__Q              1.6       1.12      1.57083     0.180978      1.30022      1.89198
# WELL_68529__Q            219.9     153.93       222.62       26.762      178.968      262.868
# WELL_69049__Q             37.6      26.32      37.3595      4.53191      30.2618      44.6771
# WELL_69970__Q             62.9      44.03      60.9153      7.14127      50.3975      75.3488
# WELL_71109__Q               15       10.5      14.7632      1.77801      12.1068      17.7598
# WELL_71110__Q               13        9.1      13.0582      1.51916      10.4074      15.4334
#
#
#   ---  initial population objective function summary:  ---
# using member 33 as nearest-to-mean single point
#     with distance of 88.1139 from mean of decision variable population
# objective function      direction         mean      std dev          min          max         knee
#
# LPR:TOTAL_COMBINED:BDPL  minimize     4.693757    0.1213081     4.439552     4.909665     4.832232
# OBJ_WELL                 maximize     4319.666     163.1781     3931.625     4589.237     4502.374
#
# ... saved initial dv population to  los_pollos_run.0.dv_pop.csv
# ...performing initial pareto dominance sort
# ...wrote pareto summary to los_pollos_run.pareto.summary.csv
# initialized archives with 13 nondominated members
# ...wrote pareto summary to los_pollos_run.pareto.archive.summary.csv
# ...wrote pareto summary to los_pollos_run.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 13 X 19 to 'los_pollos_run.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 13 X 19 to 'los_pollos_run.0.archive.dv_pop.csv'
# ...saved prior information population of size 13 X 1 to 'los_pollos_run.archive.pi_pop.csv'
# ...saved generation-specific prior information population of size 13 X 1 to 'los_pollos_run.0.archive.pi_pop.csv'
# ...saved observation population of size 13 X 330 to 'los_pollos_run.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 13 X 330 to 'los_pollos_run.0.archive.obs_pop.csv'
# ...number of initial feasible solutions: 13
#
#   ---  initialization complete  ---
#
#   ---  starting generation  1  ---
# ...generating PSO population of size 38
# ...running population of size  38
# 02/16/26 02:37:16 external run manager calling forward run command(s)
# 02/16/26 02:37:16 calling forward run command: 'python run_pycap_standalone_opt_mou.py los_pollos_run'
# ...pid: 95151
# ...exit_code: 95151
# ...status: 0
# 02/16/26 02:37:25 forward run command(s) finished, took 8.204 seconds
# ...saved decision variable population of size 38 X 19 to 'los_pollos_run.dv_pop.csv'
# ...saved generation-specific decision variable population of size 38 X 19 to 'los_pollos_run.1.dv_pop.csv'
# ...saved prior information population of size 38 X 1 to 'los_pollos_run.pi_pop.csv'
# ...saved generation-specific prior information population of size 38 X 1 to 'los_pollos_run.1.pi_pop.csv'
# ...saved observation population of size 38 X 330 to 'los_pollos_run.obs_pop.csv'
# ...saved generation-specific observation population of size 38 X 330 to 'los_pollos_run.1.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  76
# ...wrote pareto summary to los_pollos_run.pareto.summary.csv
# updating archive
# adding 13 non-dominated members to archive
# pareto dominance sorting archive of size 26
# ...wrote pareto summary to los_pollos_run.pareto.archive.summary.csv
# resizing archive from 26 to 22 current non-dominated solutions
# ...wrote pareto summary to los_pollos_run.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 22 X 19 to 'los_pollos_run.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 22 X 19 to 'los_pollos_run.1.archive.dv_pop.csv'
# ...saved prior information population of size 22 X 1 to 'los_pollos_run.archive.pi_pop.csv'
# ...saved generation-specific prior information population of size 22 X 1 to 'los_pollos_run.1.archive.pi_pop.csv'
# ...saved observation population of size 22 X 330 to 'los_pollos_run.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 22 X 330 to 'los_pollos_run.1.archive.obs_pop.csv'
# ...resizing current populations to  38
#
#   ---  generation 1 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5     193.55      253.762      35.0829       193.55      322.646
# WELL_23645__Q            158.8     111.16      155.282      17.4185       111.16      188.332
# WELL_23653__Q            263.6     184.52      247.599      29.3274       184.52      304.562
# WELL_23755__Q            794.6     556.22      812.896      97.7428       556.22      948.514
# WELL_23770__Q            239.9     167.93      236.638      25.8105       167.93      283.933
# WELL_23816__Q            149.4     104.58      143.731      15.3984       119.03      173.511
# WELL_23876__Q            197.6     138.32      191.123      19.7358       138.32       230.13
# WELL_23934__Q            370.6     259.42      349.902      25.7207      304.821      402.586
# WELL_24239__Q            271.5     190.05      258.268       26.301       200.78       323.12
# WELL_24323__Q            206.4     144.48      206.301      18.9912      159.194      247.192
# WELL_466__Q              315.9     221.13      307.497      36.6737      229.184      378.944
# WELL_467__Q              296.9     207.83      281.124      34.3989       207.83      350.011
# WELL_58405__Q              418      292.6      398.796      44.3422        292.6       471.23
# WELL_68008__Q              1.6       1.12      1.52998     0.157708       1.2073      1.88166
# WELL_68529__Q            219.9     153.93      218.271      24.7978       153.93      262.868
# WELL_69049__Q             37.6      26.32      36.2347      3.15773      29.5231      42.0141
# WELL_69970__Q             62.9      44.03      60.1544      5.28052      47.8203      72.8933
# WELL_71109__Q               15       10.5      14.6948      1.38689      12.2058      17.7598
# WELL_71110__Q               13        9.1      13.0624      1.02467      10.4861      15.4334
#
#
#   ---  generation 1 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q           27.1396     9.66161     5.12377     1.56322     30.3821     13.5676
# WELL_23645__Q           2.50933     1.59028           0           0     18.5489     14.3004
# WELL_23653__Q           16.3419     6.19151     10.8694     3.44587     28.3652     13.3242
# WELL_23755__Q          -6.78297   -0.841441           0           0     96.0833     14.7299
# WELL_23770__Q           7.46429     3.05786           0           0     24.9702     12.9446
# WELL_23816__Q           5.07642     3.41141    0.275831    0.158718      3.7598     3.06199
# WELL_23876__Q         -0.558866    -0.29327      3.9983     1.70774      21.166     13.2714
# WELL_23934__Q           20.3425     5.49433     40.7456     9.19077    -1.42283   -0.468964
# WELL_24239__Q            9.8772     3.68353     1.05419    0.325194     17.0753     7.83792
# WELL_24323__Q           5.50265       2.598           0           0     6.59783     3.97959
# WELL_466__Q             6.85048     2.17927           0           0     26.6507     10.4171
# WELL_467__Q             12.2426     4.17313     2.74822    0.779065     35.2734     14.5096
# WELL_58405__Q           20.4551     4.87897     14.5273     2.99065     43.9387     13.0561
# WELL_68008__Q         0.0408421     2.60004   0.0103194     0.54543   0.0929257     7.14691
# WELL_68529__Q           4.34921     1.95365           0           0     25.0381     13.9903
# WELL_69049__Q           1.12478     3.01069       2.663     5.96055    0.738695     2.44101
# WELL_69970__Q          0.760873     1.24907     2.45549     3.25883      2.5772     5.11375
# WELL_71109__Q         0.0684083     0.46337           0           0  -0.0990351   -0.818012
# WELL_71110__Q       -0.00412161  -0.0315633           0           0  -0.0786621   -0.755827
#
#
#   ---  generation 1 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=1_MEMBER=20_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function      direction         mean      std dev          min          max         knee
#
# LPR:TOTAL_COMBINED:BDPL  minimize     4.567678    0.1710314     4.299277     4.901475     4.299277
# OBJ_WELL                 maximize     4186.866     235.2816     3738.419     4589.237     3804.154
#
#
#   ---  generation 1 objective function change summary:  ---
# objective function      mean change    % change  max change    % change  min change    % change knee change    % change
# LPR:TOTAL_COMBINED:BDPL    0.126079      2.6861  0.00818985    0.166811    0.140275     3.15967    0.532956     11.0292
# OBJ_WELL                      132.8     3.07432           0           0     193.206     4.91416      698.22     15.5078
#
# ...number of feasible solutions at the end of generation 1: 22
#
#   ---  starting generation  2  ---
# ...generating PSO population of size 38
# ...running population of size  38
# 02/16/26 02:37:25 external run manager calling forward run command(s)
# 02/16/26 02:37:25 calling forward run command: 'python run_pycap_standalone_opt_mou.py los_pollos_run'
# ...pid: 95205
# ...exit_code: 95205
# ...status: 0
# 02/16/26 02:37:33 forward run command(s) finished, took 8.185 seconds
# ...saved decision variable population of size 38 X 19 to 'los_pollos_run.dv_pop.csv'
# ...saved generation-specific decision variable population of size 38 X 19 to 'los_pollos_run.2.dv_pop.csv'
# ...saved prior information population of size 38 X 1 to 'los_pollos_run.pi_pop.csv'
# ...saved generation-specific prior information population of size 38 X 1 to 'los_pollos_run.2.pi_pop.csv'
# ...saved observation population of size 38 X 330 to 'los_pollos_run.obs_pop.csv'
# ...saved generation-specific observation population of size 38 X 330 to 'los_pollos_run.2.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  76
# ...wrote pareto summary to los_pollos_run.pareto.summary.csv
# updating archive
# adding 12 non-dominated members to archive
# pareto dominance sorting archive of size 34
# ...wrote pareto summary to los_pollos_run.pareto.archive.summary.csv
# resizing archive from 34 to 29 current non-dominated solutions
# ...wrote pareto summary to los_pollos_run.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 29 X 19 to 'los_pollos_run.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 29 X 19 to 'los_pollos_run.2.archive.dv_pop.csv'
# ...saved prior information population of size 29 X 1 to 'los_pollos_run.archive.pi_pop.csv'
# ...saved generation-specific prior information population of size 29 X 1 to 'los_pollos_run.2.archive.pi_pop.csv'
# ...saved observation population of size 29 X 330 to 'los_pollos_run.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 29 X 330 to 'los_pollos_run.2.archive.obs_pop.csv'
# ...resizing current populations to  38
#
#   ---  generation 2 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5     193.55      244.136      34.9074       193.55      322.646
# WELL_23645__Q            158.8     111.16      156.519      16.2904       111.16      188.332
# WELL_23653__Q            263.6     184.52       232.97      35.3103       184.52      304.562
# WELL_23755__Q            794.6     556.22      809.359      92.9406       556.22      948.514
# WELL_23770__Q            239.9     167.93      239.324      24.4044       167.93      283.933
# WELL_23816__Q            149.4     104.58      146.037       12.627       122.79      172.399
# WELL_23876__Q            197.6     138.32      192.357      17.8844       138.32       230.13
# WELL_23934__Q            370.6     259.42      349.768      25.8807      294.081      402.586
# WELL_24239__Q            271.5     190.05      263.507      23.4225      218.693       323.12
# WELL_24323__Q            206.4     144.48       205.61      16.8235      167.975      247.192
# WELL_466__Q              315.9     221.13      300.282      40.8624       221.13      378.944
# WELL_467__Q              296.9     207.83      276.071      37.5594       207.83      350.011
# WELL_58405__Q              418      292.6      401.095      43.7036        292.6       471.23
# WELL_68008__Q              1.6       1.12      1.47568      0.16351      1.13633      1.88166
# WELL_68529__Q            219.9     153.93      209.278      27.8156       153.93      262.868
# WELL_69049__Q             37.6      26.32      35.2744      3.66724      26.9522      41.8567
# WELL_69970__Q             62.9      44.03      59.1923       5.7524        44.03      72.8933
# WELL_71109__Q               15       10.5      14.6104      1.37299      12.2058      17.7598
# WELL_71110__Q               13        9.1      12.9251     0.982034      10.4861      15.4334
#
#
#   ---  generation 2 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q           9.62595      3.7933           0           0           0           0
# WELL_23645__Q          -1.23653   -0.796312           0           0           0           0
# WELL_23653__Q           14.6284     5.90812           0           0           0           0
# WELL_23755__Q           3.53703    0.435114           0           0           0           0
# WELL_23770__Q          -2.68672    -1.13537           0           0           0           0
# WELL_23816__Q          -2.30693    -1.60504     1.11139    0.640534     -3.7598    -3.15871
# WELL_23876__Q          -1.23446   -0.645897           0           0           0           0
# WELL_23934__Q          0.134156    0.038341           0           0     10.7403     3.52346
# WELL_24239__Q          -5.23877    -2.02843           0           0    -17.9129    -8.92169
# WELL_24323__Q          0.690641    0.334774           0           0    -8.78081    -5.51579
# WELL_466__Q             7.21482      2.3463           0           0     8.05402     3.51421
# WELL_467__Q             5.05299     1.79742           0           0           0           0
# WELL_58405__Q          -2.29935   -0.576574           0           0           0           0
# WELL_68008__Q         0.0543014     3.54915           0           0   0.0709695     5.87838
# WELL_68529__Q           8.99275     4.11999           0           0           0           0
# WELL_69049__Q          0.960351     2.65036    0.157397    0.374628     2.57099     8.70838
# WELL_69970__Q          0.962063     1.59932           0           0     3.79035     7.92622
# WELL_71109__Q           0.08437    0.574148           0           0           0           0
# WELL_71110__Q          0.137232     1.05059           0           0           0           0
#
#
#   ---  generation 2 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=2_MEMBER=63_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function      direction         mean      std dev          min          max         knee
#
# LPR:TOTAL_COMBINED:BDPL  minimize     4.519023     0.199834     4.167934     4.901475     4.167934
# OBJ_WELL                 maximize     4149.793     255.5985     3602.273     4589.237     3602.273
#
#
#   ---  generation 2 objective function change summary:  ---
# objective function      mean change    % change  max change    % change  min change    % change knee change    % change
# LPR:TOTAL_COMBINED:BDPL   0.0486553     1.06521           0           0    0.131343     3.05499    0.131343     3.05499
# OBJ_WELL                    37.0723    0.885443           0           0     136.146     3.64182     201.881     5.30686
#
# ...number of feasible solutions at the end of generation 2: 29
#
#   ---  starting generation  3  ---
# ...generating PSO population of size 38
# ...running population of size  38
# 02/16/26 02:37:33 external run manager calling forward run command(s)
# 02/16/26 02:37:33 calling forward run command: 'python run_pycap_standalone_opt_mou.py los_pollos_run'
# ...pid: 95266
# ...exit_code: 95266
# ...status: 0
# 02/16/26 02:37:41 forward run command(s) finished, took 8.197 seconds
# ...saved decision variable population of size 38 X 19 to 'los_pollos_run.dv_pop.csv'
# ...saved generation-specific decision variable population of size 38 X 19 to 'los_pollos_run.3.dv_pop.csv'
# ...saved prior information population of size 38 X 1 to 'los_pollos_run.pi_pop.csv'
# ...saved generation-specific prior information population of size 38 X 1 to 'los_pollos_run.3.pi_pop.csv'
# ...saved observation population of size 38 X 330 to 'los_pollos_run.obs_pop.csv'
# ...saved generation-specific observation population of size 38 X 330 to 'los_pollos_run.3.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  76
# ...wrote pareto summary to los_pollos_run.pareto.summary.csv
# updating archive
# adding 9 non-dominated members to archive
# pareto dominance sorting archive of size 38
# ...wrote pareto summary to los_pollos_run.pareto.archive.summary.csv
# resizing archive from 38 to 33 current non-dominated solutions
# ...wrote pareto summary to los_pollos_run.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 33 X 19 to 'los_pollos_run.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 33 X 19 to 'los_pollos_run.3.archive.dv_pop.csv'
# ...saved prior information population of size 33 X 1 to 'los_pollos_run.archive.pi_pop.csv'
# ...saved generation-specific prior information population of size 33 X 1 to 'los_pollos_run.3.archive.pi_pop.csv'
# ...saved observation population of size 33 X 330 to 'los_pollos_run.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 33 X 330 to 'los_pollos_run.3.archive.obs_pop.csv'
# ...resizing current populations to  38
#
#   ---  generation 3 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5     193.55      241.692      38.6372       193.55      322.646
# WELL_23645__Q            158.8     111.16       153.83      18.0612       111.16      188.332
# WELL_23653__Q            263.6     184.52      231.692      35.6141       184.52      304.562
# WELL_23755__Q            794.6     556.22      807.497      84.8924       556.22      946.832
# WELL_23770__Q            239.9     167.93      240.522      22.8482       167.93      283.933
# WELL_23816__Q            149.4     104.58      145.195      12.1927       122.79      166.955
# WELL_23876__Q            197.6     138.32      193.256      15.7554       138.32       230.13
# WELL_23934__Q            370.6     259.42      351.667      26.2185      293.624      402.586
# WELL_24239__Q            271.5     190.05      262.422      21.4014      197.817      303.934
# WELL_24323__Q            206.4     144.48      206.531      15.9651      167.975      247.192
# WELL_466__Q              315.9     221.13      292.875      43.3904       221.13      378.944
# WELL_467__Q              296.9     207.83      265.773      37.7771       207.83      346.112
# WELL_58405__Q              418      292.6      403.286      43.2461        292.6       471.23
# WELL_68008__Q              1.6       1.12       1.3926     0.181673         1.12      1.88166
# WELL_68529__Q            219.9     153.93      202.294      30.3859       153.93      262.868
# WELL_69049__Q             37.6      26.32      34.9797      3.92457        26.32      41.7165
# WELL_69970__Q             62.9      44.03      58.9553       6.3896        44.03      72.8933
# WELL_71109__Q               15       10.5      14.4128       1.3288         10.5      17.4727
# WELL_71110__Q               13        9.1      12.6207      1.16404      9.65783      15.4334
#
#
#   ---  generation 3 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q            2.4438       1.001           0           0           0           0
# WELL_23645__Q           2.68902     1.71802           0           0           0           0
# WELL_23653__Q           1.27801    0.548571           0           0           0           0
# WELL_23755__Q             1.862    0.230059     1.68197    0.177327           0           0
# WELL_23770__Q          -1.19764   -0.500425           0           0           0           0
# WELL_23816__Q          0.842024    0.576581     5.44466     3.15817           0           0
# WELL_23876__Q         -0.898951   -0.467335           0           0           0           0
# WELL_23934__Q          -1.89866   -0.542835           0           0    0.457402    0.155536
# WELL_24239__Q           1.08412     0.41142     19.1857     5.93765     20.8756     9.54566
# WELL_24323__Q         -0.920537    -0.44771           0           0           0           0
# WELL_466__Q             7.40694     2.46666           0           0           0           0
# WELL_467__Q             10.2988     3.73048     3.89878      1.1139           0           0
# WELL_58405__Q          -2.19129   -0.546328           0           0           0           0
# WELL_68008__Q         0.0830827     5.63012           0           0   0.0163263     1.43676
# WELL_68529__Q           6.98461     3.33747           0           0           0           0
# WELL_69049__Q          0.294632    0.835258    0.140273    0.335127     0.63216     2.34549
# WELL_69970__Q          0.237092    0.400545           0           0           0           0
# WELL_71109__Q           0.19762      1.3526    0.287091     1.61653     1.70583     13.9755
# WELL_71110__Q          0.304455     2.35553           0           0    0.828264      7.8987
#
#
#   ---  generation 3 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=3_MEMBER=105_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function      direction         mean      std dev          min          max         knee
#
# LPR:TOTAL_COMBINED:BDPL  minimize     4.489405    0.2152354     4.017573     4.901475     4.017573
# OBJ_WELL                 maximize     4120.894     272.5949     3408.528     4589.237     3408.528
#
#
#   ---  generation 3 objective function change summary:  ---
# objective function      mean change    % change  max change    % change  min change    % change knee change    % change
# LPR:TOTAL_COMBINED:BDPL   0.0296174    0.655394           0           0    0.150361     3.60757    0.150361     3.60757
# OBJ_WELL                    28.8991    0.696398           0           0     193.744     5.37839     193.744     5.37839
#
# ...number of feasible solutions at the end of generation 3: 33
#
#   ---  starting generation  4  ---
# ...generating PSO population of size 38
# ...running population of size  38
# 02/16/26 02:37:41 external run manager calling forward run command(s)
# 02/16/26 02:37:41 calling forward run command: 'python run_pycap_standalone_opt_mou.py los_pollos_run'
# ...pid: 95328
# ...exit_code: 95328
# ...status: 0
# 02/16/26 02:37:50 forward run command(s) finished, took 8.255 seconds
# ...saved decision variable population of size 38 X 19 to 'los_pollos_run.dv_pop.csv'
# ...saved generation-specific decision variable population of size 38 X 19 to 'los_pollos_run.4.dv_pop.csv'
# ...saved prior information population of size 38 X 1 to 'los_pollos_run.pi_pop.csv'
# ...saved generation-specific prior information population of size 38 X 1 to 'los_pollos_run.4.pi_pop.csv'
# ...saved observation population of size 38 X 330 to 'los_pollos_run.obs_pop.csv'
# ...saved generation-specific observation population of size 38 X 330 to 'los_pollos_run.4.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  76
# ...wrote pareto summary to los_pollos_run.pareto.summary.csv
# updating archive
# adding 10 non-dominated members to archive
# pareto dominance sorting archive of size 43
# ...wrote pareto summary to los_pollos_run.pareto.archive.summary.csv
# resizing archive from 43 to 40 current non-dominated solutions
# ...wrote pareto summary to los_pollos_run.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 40 X 19 to 'los_pollos_run.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 40 X 19 to 'los_pollos_run.4.archive.dv_pop.csv'
# ...saved prior information population of size 40 X 1 to 'los_pollos_run.archive.pi_pop.csv'
# ...saved generation-specific prior information population of size 40 X 1 to 'los_pollos_run.4.archive.pi_pop.csv'
# ...saved observation population of size 40 X 330 to 'los_pollos_run.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 40 X 330 to 'los_pollos_run.4.archive.obs_pop.csv'
# ...resizing current populations to  38
#
#   ---  generation 4 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5     193.55      234.031        38.01       193.55      322.646
# WELL_23645__Q            158.8     111.16      152.647      16.7692       111.16       183.62
# WELL_23653__Q            263.6     184.52      224.334      35.1282       184.52      304.562
# WELL_23755__Q            794.6     556.22      792.628      86.7948       556.22      946.832
# WELL_23770__Q            239.9     167.93      238.308      19.8072      171.716      283.933
# WELL_23816__Q            149.4     104.58      145.801         11.6      114.421      166.955
# WELL_23876__Q            197.6     138.32      189.279      17.8058       138.32       224.19
# WELL_23934__Q            370.6     259.42      343.762      36.2003       259.42      402.586
# WELL_24239__Q            271.5     190.05      262.708      20.4965       190.05      303.934
# WELL_24323__Q            206.4     144.48      205.267      14.1784      167.975      243.995
# WELL_466__Q              315.9     221.13       275.64      39.8673       221.13      377.808
# WELL_467__Q              296.9     207.83      262.542      37.9139       207.83      328.523
# WELL_58405__Q              418      292.6      404.263      40.7236        292.6       471.23
# WELL_68008__Q              1.6       1.12      1.37162     0.193792         1.12      1.88166
# WELL_68529__Q            219.9     153.93      195.799      31.9896       153.93      262.868
# WELL_69049__Q             37.6      26.32      33.8572      4.07312        26.32      41.5104
# WELL_69970__Q             62.9      44.03      58.6318      6.82427        44.03      72.8933
# WELL_71109__Q               15       10.5      14.5165      1.21836         10.5      17.4727
# WELL_71110__Q               13        9.1      12.4535      1.37631          9.1      15.4334
#
#
#   ---  generation 4 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q           7.66098     3.16972           0           0           0           0
# WELL_23645__Q            1.1827    0.768838     4.71154     2.50173           0           0
# WELL_23653__Q           7.35809      3.1758           0           0           0           0
# WELL_23755__Q           14.8691     1.84138           0           0           0           0
# WELL_23770__Q            2.2141    0.920539           0           0      -3.786    -2.25451
# WELL_23816__Q         -0.605354   -0.416924           0           0     8.36885      6.8156
# WELL_23876__Q           3.97757     2.05818     5.93936     2.58088           0           0
# WELL_23934__Q           7.90466     2.24777           0           0     34.2036     11.6488
# WELL_24239__Q         -0.285312   -0.108723           0           0     7.76692     3.92632
# WELL_24323__Q           1.26308    0.611571     3.19721     1.29341           0           0
# WELL_466__Q             17.2354     5.88489     1.13529    0.299593           0           0
# WELL_467__Q             3.23104     1.21572     17.5894     5.08198           0           0
# WELL_58405__Q         -0.977116   -0.242288           0           0           0           0
# WELL_68008__Q         0.0209755     1.50621           0           0           0           0
# WELL_68529__Q           6.49483     3.21059           0           0           0           0
# WELL_69049__Q           1.12255     3.20914    0.206065    0.493966           0           0
# WELL_69970__Q          0.323496    0.548715           0           0           0           0
# WELL_71109__Q           -0.1037   -0.719499           0           0           0           0
# WELL_71110__Q          0.167137     1.32431           0           0    0.557827     5.77591
#
#
#   ---  generation 4 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=4_MEMBER=120_PSO as single, 'optimal' point
#    with distance of 0 from optimal trade - off
# objective function      direction         mean      std dev          min          max         knee
#
# LPR:TOTAL_COMBINED:BDPL  minimize     4.421045    0.2206864     3.995979     4.897712     3.995979
# OBJ_WELL                 maximize      4047.84     277.5916     3455.323     4589.237     3455.323
#
#
#   ---  generation 4 objective function change summary:  ---
# objective function      mean change    % change  max change    % change  min change    % change knee change    % change
# LPR:TOTAL_COMBINED:BDPL   0.0683602      1.5227  0.00376366   0.0767864   0.0215941     0.53749   0.0215941     0.53749
# OBJ_WELL                    73.0542     1.77278           0           0    -46.7946    -1.37287    -46.7946    -1.37287
#
# ...number of feasible solutions at the end of generation 4: 40
#
#   ---  starting generation  5  ---
# ...generating PSO population of size 38
# ...running population of size  38
# 02/16/26 02:37:50 external run manager calling forward run command(s)
# 02/16/26 02:37:50 calling forward run command: 'python run_pycap_standalone_opt_mou.py los_pollos_run'
# ...pid: 95390
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pyemu.os_utils.run(f"pestpp-mou {run_name}.pst /e",cwd=str(run_path))
#
# File ~/Documents/classes/4th-sem/564 Analysis/.venv/lib/python3.12/site-packages/pyemu/utils/os_utils.py:108, in run(cmd_str, cwd, verbose, use_sp, **kwargs)
#     106     run_sp(cmd_str, cwd, verbose, **kwargs)
#     107 else:
# --> 108     run_ossystem(cmd_str, cwd, verbose)
#
# File ~/Documents/classes/4th-sem/564 Analysis/.venv/lib/python3.12/site-packages/pyemu/utils/os_utils.py:170, in run_ossystem(cmd_str, cwd, verbose)
#     168 estat = os.WEXITSTATUS(ret_val)
#     169 if estat != 0 or ret_val != 0:
# --> 170     raise Exception("run() returned non-zero: {0},{1}".format(estat,ret_val))
#
# Exception: run() returned non-zero: 0,2
# Traceback (most recent call last):
#   File "/Users/nkalauni/Documents/classes/4th-sem/564 Analysis/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_los_pollos_run/run_pycap_standalone_opt_mou.py", line 90, in <module>
#     standalone_worker(initial_dict, bdplobs,rootname=sys.argv[1])
#   File "/Users/nkalauni/Documents/classes/4th-sem/564 Analysis/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_los_pollos_run/run_pycap_standalone_opt_mou.py", line 78, in standalone_worker
#     results = list(executor.map(process_realization, args_list))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nkalauni/.local/share/uv/python/cpython-3.12.5-macos-aarch64-none/lib/python3.12/concurrent/futures/process.py", line 642, in _chain_from_iterable_of_lists
#     for element in iterable:
#                    ^^^^^^^^
#   File "/Users/nkalauni/.local/share/uv/python/cpython-3.12.5-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nkalauni/.local/share/uv/python/cpython-3.12.5-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/nkalauni/.local/share/uv/python/cpython-3.12.5-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 451, in result
#     self._condition.wait(timeout)
#   File "/Users/nkalauni/.local/share/uv/python/cpython-3.12.5-macos-aarch64-none/lib/python3.12/threading.py", line 355, in wait
#     waiter.acquire()
# KeyboardInterrupt

# %% [markdown]
# ### Finally, this last cell will compress the results to save diskspace. It will also delete the original files. This is a required step because the postprocessing will only work with the compressed files!

# %%
# zip up all the results
for cf in run_path.glob('*.csv'):
    if "_pop" in cf.name or "archive" in cf.name or "summary" in cf.name:
        with zipfile.ZipFile(cf.with_suffix('.csv.zip'), 'w', compression=zipfile.ZIP_DEFLATED, compresslevel=9) as ofp:
            ofp.write(cf, arcname=cf.name)
        cf.unlink()

# %%
run_path
# Out:
# PosixPath('../pycap_runs/pycap_pest/run_ant_group_run')
